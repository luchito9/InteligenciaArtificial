# %% [markdown]
# Aplicar una regresión polinómica a este conjunto de datos estructurado para clasificación binaria  no sería una buena idea y no proporcionaría resultados útiles para resolver el problema de clasificación binaria.
#  TEnemos que seleccionar el método de modelado correcto que se adapte a la naturaleza de los datos y el tipo de problema que se está abordando.
#
#  ya que hay dataset demasiados estructurados
#
#  2-fallsos
